# %% [markdown]
# <a href="https://colab.research.google.com/github/torettdom/mycode/blob/main/day_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import read_csv
import seaborn as sns
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2,f_regression,f_classif
dataframe=sns.load_dataset('tips')
dataframe
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
dataframe['sex']=lb.fit_transform(dataframe['sex'])
dataframe['smoker']=lb.fit_transform(dataframe['smoker'])
dataframe['day']=lb.fit_transform(dataframe['day'])
dataframe['time']=lb.fit_transform(dataframe['time'])

# %%
x=dataframe.drop('tip',axis=1)
y=dataframe.tip

# %%
x
# Out:
#      total_bill  sex  smoker  day  time  size
# 0         16.99    0       0    2     0     2
# 1         10.34    1       0    2     0     3
# 2         21.01    1       0    2     0     3
# 3         23.68    1       0    2     0     2
# 4         24.59    0       0    2     0     4
# ..          ...  ...     ...  ...   ...   ...
# 239       29.03    1       0    1     0     3
# 240       27.18    0       1    1     0     2
# 241       22.67    1       1    1     0     2
# 242       17.82    1       0    1     0     2
# 243       18.78    0       0    3     0     2
#
# [244 rows x 6 columns]

# %%
test=SelectKBest(score_func=f_regression,k=3).fit(x,y)
test
# Out:
# SelectKBest(k=3, score_func=<function f_regression at 0x7853d5e03740>)

# %%
np.round(test.scores_,2)
# Out:
# array([2.0336e+02, 1.9300e+00, 1.0000e-02, 3.0000e-02, 3.6300e+00,
#        7.6180e+01])

# %%
np.round(test.pvalues_,3)
# Out:
# array([0.   , 0.166, 0.927, 0.858, 0.058, 0.   ])

# %%
test.scores_
# Out:
# array([2.03357723e+02, 1.92615456e+00, 8.50601355e-03, 3.22744400e-02,
#        3.63381548e+00, 7.61754260e+01])

# %%
dataframe.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
np.round(test.pvalues_,3)
# Out:
# array([0.   , 0.166, 0.927, 0.858, 0.058, 0.   ])

# %%
# Instead of using get_features_names_out, use the following approach:

selected_features_mask = test.get_support()  # Get a boolean mask of selected features
selected_features = x.columns[selected_features_mask]  # Get the names of selected features

print(selected_features)  # Print the selected feature names
# Out:
# Index(['total_bill', 'time', 'size'], dtype='object')

# %%
test.get_feature_names_out()
# Out:
# array(['total_bill', 'time', 'size'], dtype=object)

# %%
#For regression: f_regression, mutual_info_regression
#For classsification: chi2, f_classif, Mutual_info_classif

# %%
df=sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['species']=lb.fit_transform(df['species'])

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
# x: DataFrame with species column
x = df.copy()

# y: DataFrame without species column
y = df.drop(columns=['species'])

# Display the first few rows
print("X (with species):\n", x.head())
print("\nY (without species):\n", y.head())
# Out:
# X (with species):
#     sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0
#
# Y (without species):
#     sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
#iloc method is used for indexing and slicing
x=df.iloc[:,0:4]
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y=df['species']

y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64

# %%
sel=SelectKBest(score_func=f_classif,k=3).fit(x,y)
sel
# Out:
# SelectKBest(k=3)

# %%
sel.pvalues_
# Out:
# array([1.66966919e-31, 4.49201713e-17, 2.85677661e-91, 4.16944584e-85])

# %%
sel.scores_
# Out:
# array([ 119.26450218,   49.16004009, 1180.16118225,  960.0071468 ])

# %%
df.columns[np.where(sel.get_support(indices=True))]
# Out:
# Index(['sepal_width', 'petal_length'], dtype='object')
